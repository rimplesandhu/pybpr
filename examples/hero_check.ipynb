# %%
import sys
print(sys.executable)
print(sys.prefix)
# Out:
# /kfs2/projects/zazzle/pybpr/.venv/bin/python
# /kfs2/projects/zazzle/pybpr/.venv

# %%
import os
import json
import time
import hero
import numpy as np

# %%
hero_client = hero.HeroClient()
model_registry = hero_client.MLModelRegistry()
mlflow = model_registry.get_patched_mlflow()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 hero_client = hero.HeroClient()
#       2 model_registry = hero_client.MLModelRegistry()
#       3 mlflow = model_registry.get_patched_mlflow()
#
# File /kfs2/projects/zazzle/pybpr/.venv/lib/python3.12/site-packages/hero/client.py:29, in HeroClient.__init__(self)
#      27 self.env = get_env()
#      28 self.api = Session()
# ---> 29 client_id, client_secret = get_client_credentials()
#      30 self._client_id = client_id
#      31 self._client_secret = client_secret
#
# File /kfs2/projects/zazzle/pybpr/.venv/lib/python3.12/site-packages/hero/lib/config.py:30, in get_client_credentials()
#      27 def get_client_credentials():
#      28     """Returns the client credentials tuple (client_id, client_secret) from the environment variables HERO_CLIENT_ID and HERO_CLIENT_SECRET"""
#      29     client_credentials = (
# ---> 30         os.environ["HERO_CLIENT_ID"],
#      31         os.environ["HERO_CLIENT_SECRET"],
#      32     )
#      33     return client_credentials
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/os.py:714, in _Environ.__getitem__(self, key)
#     711     value = self._data[self.encodekey(key)]
#     712 except KeyError:
#     713     # raise KeyError with the original key value
# --> 714     raise KeyError(key) from None
#     715 return self.decodevalue(value)
#
# KeyError: 'HERO_CLIENT_ID'
